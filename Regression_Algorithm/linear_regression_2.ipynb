# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf 
import seaborn as sns

# %%
adv_df= pd.read_csv('../Data_Files/Supervise_learning/Advertising.csv')
adv_df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Data distribution of TV variable

# %%
plt.Figure(figsize=(8,6))
sns.scatterplot(adv_df['TV'])
# Out:
# <Axes: ylabel='TV'>

# %%
sns.scatterplot(adv_df['radio'])
# Out:
# <Axes: ylabel='radio'>

# %%
sns.scatterplot(adv_df['sales'])
# Out:
# <Axes: ylabel='sales'>

# %%
sns.scatterplot(adv_df['newspaper'])
# Out:
# <Axes: ylabel='newspaper'>
